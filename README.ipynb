# %% [markdown]
# <a href="https://colab.research.google.com/github/tarekkanon/AdventureWorks/blob/main/README.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import pandas as pd
import datetime as dt

# %%
# options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %%
df_sales = pd.read_csv('/content/drive/MyDrive/AnalysisData/fact_sales.csv', encoding='latin-1')
df_customers = pd.read_csv('/content/drive/MyDrive/AnalysisData/dim_customers.csv', encoding='latin-1')
df_sales_territory = pd.read_csv('/content/drive/MyDrive/AnalysisData/dim_sales_terrotry.csv', encoding='latin-1')
df_dates = pd.read_csv('/content/drive/MyDrive/AnalysisData/dim_date.csv', encoding='latin-1')
df_products = pd.read_csv('/content/drive/MyDrive/AnalysisData/dim_products.csv', encoding='latin-1')
df_geography = pd.read_csv('/content/drive/MyDrive/AnalysisData/dim_geography.csv', encoding='latin-1')

# %%
df_customers
# Out:
#        CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName  \
# 0            11000            26           AW00011000   NaN        Jon
# 1            11001            37           AW00011001   NaN     Eugene
# 2            11002            31           AW00011002   NaN      Ruben
# 3            11003            11           AW00011003   NaN    Christy
# 4            11004            19           AW00011004   NaN  Elizabeth
# ...            ...           ...                  ...   ...        ...
# 18479        29479           209           AW00029479   NaN      Tommy
# 18480        29480           248           AW00029480   NaN       Nina
# 18481        29481           120           AW00029481   NaN       Ivan
# 18482        29482           179           AW00029482   NaN    Clayton
# 18483        29483           217           AW00029483   NaN      Jésus
#
#       MiddleName LastName  NameStyle  BirthDate MaritalStatus Suffix Gender  \
# 0              V     Yang      False  23-Dec-62             M    NaN      M
# 1              L    Huang      False  23-Jun-76             S    NaN      M
# 2            NaN   Torres      False  19-Aug-66             M    NaN      M
# 3            NaN      Zhu      False  09-Dec-87             S    NaN      F
# 4            NaN  Johnson      False  06-Jun-90             S    NaN      F
# ...          ...      ...        ...        ...           ...    ...    ...
# 18479          L     Tang      False  13-May-96             M    NaN      M
# 18480          W     Raji      False  21-Sep-71             S    NaN      F
# 18481        NaN     Suri      False  16-Nov-93             S    NaN      M
# 18482        NaN    Zhang      False  08-Apr-78             M    NaN      M
# 18483          L  Navarro      False  08-May-86             M    NaN      M
#
#                          EmailAddress YearlyIncome  TotalChildren  \
# 0           jon24@adventure-works.com   $90,000.00              2
# 1        eugene10@adventure-works.com   $60,000.00              3
# 2         ruben35@adventure-works.com   $60,000.00              3
# 3       christy12@adventure-works.com   $70,000.00              0
# 4      elizabeth5@adventure-works.com   $80,000.00              5
# ...                               ...          ...            ...
# 18479      tommy2@adventure-works.com   $30,000.00              1
# 18480      nina21@adventure-works.com   $30,000.00              3
# 18481       ivan0@adventure-works.com   $30,000.00              3
# 18482    clayton0@adventure-works.com   $30,000.00              3
# 18483      jésus9@adventure-works.com   $30,000.00              0
#
#        NumberChildrenAtHome EnglishEducation       SpanishEducation  \
# 0                         0        Bachelors           Licenciatura
# 1                         3        Bachelors           Licenciatura
# 2                         3        Bachelors           Licenciatura
# 3                         0        Bachelors           Licenciatura
# 4                         5        Bachelors           Licenciatura
# ...                     ...              ...                    ...
# 18479                     0  Graduate Degree  Estudios de postgrado
# 18480                     0  Graduate Degree  Estudios de postgrado
# 18481                     0  Graduate Degree  Estudios de postgrado
# 18482                     0        Bachelors           Licenciatura
# 18483                     0        Bachelors           Licenciatura
#
#       FrenchEducation EnglishOccupation SpanishOccupation FrenchOccupation  \
# 0             Bac + 4      Professional       Profesional            Cadre
# 1             Bac + 4      Professional       Profesional            Cadre
# 2             Bac + 4      Professional       Profesional            Cadre
# 3             Bac + 4      Professional       Profesional            Cadre
# 4             Bac + 4      Professional       Profesional            Cadre
# ...               ...               ...               ...              ...
# 18479         Bac + 3          Clerical    Administrativo          Employé
# 18480         Bac + 3          Clerical    Administrativo          Employé
# 18481         Bac + 3          Clerical    Administrativo          Employé
# 18482         Bac + 4          Clerical    Administrativo          Employé
# 18483         Bac + 4          Clerical    Administrativo          Employé
#
#        HouseOwnerFlag  NumberCarsOwned               AddressLine1  \
# 0                   1                0            3761 N. 14th St
# 1                   0                1                 2243 W St.
# 2                   1                1           5844 Linden Land
# 3                   0                1           1825 Village Pl.
# 4                   1                4        7553 Harness Circle
# ...               ...              ...                        ...
# 18479               1                0          111, rue Maillard
# 18480               1                0          9 Katherine Drive
# 18481               0                0                Knaackstr 4
# 18482               1                0     1080, quai de Grenelle
# 18483               1                0  244, rue de la Centenaire
#
#       AddressLine2                Phone DateFirstPurchase CommuteDistance
# 0              NaN  1 (11) 500 555-0162         22-Jul-05       1-2 Miles
# 1              NaN  1 (11) 500 555-0110         18-Jul-05       0-1 Miles
# 2              NaN  1 (11) 500 555-0184         10-Jul-05       2-5 Miles
# 3              NaN  1 (11) 500 555-0162         01-Jul-05      5-10 Miles
# 4              NaN  1 (11) 500 555-0131         26-Jul-05       1-2 Miles
# ...            ...                  ...               ...             ...
# 18479          NaN  1 (11) 500 555-0136         08-Mar-07       0-1 Miles
# 18480          NaN  1 (11) 500 555-0146         18-Jan-08       0-1 Miles
# 18481          NaN  1 (11) 500 555-0144         13-Feb-06       0-1 Miles
# 18482          NaN  1 (11) 500 555-0137         22-Mar-07       0-1 Miles
# 18483          NaN  1 (11) 500 555-0141         13-Mar-07       0-1 Miles
#
# [18484 rows x 29 columns]

# %%
# fixing date issue wrong century #BUG with python library

def fix_date(x):

    if x.year > 2024:
        year = x.year - 100
    elif x.year < 1900:
        year = x.year + 100
    else:
        year = x.year

    return dt.date(year,x.month,x.day)

# %%
# fix dates first
df_customers["BirthDate"] = pd.to_datetime(df_customers['BirthDate'])
df_customers["BirthDate"] = df_customers["BirthDate"].apply(fix_date)

# add calculated column for age
df_customers['age'] = df_customers["BirthDate"].apply(lambda x : (pd.datetime.now().year - x.year))
# Out:
# <ipython-input-6-3d19f54c3c4e>:6: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   df_customers['age'] = df_customers["BirthDate"].apply(lambda x : (pd.datetime.now().year - x.year))

# %%
df_customers["BirthDate"]
# Out:
# 0        1962-12-23
# 1        1976-06-23
# 2        1966-08-19
# 3        1987-12-09
# 4        1990-06-06
#             ...
# 18479    1996-05-13
# 18480    1971-09-21
# 18481    1993-11-16
# 18482    1978-04-08
# 18483    1986-05-08
# Name: BirthDate, Length: 18484, dtype: object

# %%
# average age of customers
cust_avg_age = df_customers['age'].mean()

# total customers
total_customers = df_customers['CustomerKey'].count()

# total distinct customers (making sure no duplicates)
total_unqiue_customers = len(pd.unique(df_customers['CustomerKey']))

# %%
print('Customers average age: ' + str(cust_avg_age))
print('Total count of customers: ' + str(total_customers))
print('Total unique count of customers: ' + str(total_unqiue_customers))
# Out:
# Customers average age: 44.45017312270071
# Total count of customers: 18484
# Total unique count of customers: 18484

# %%
df_sales
# Out:
#        ProductKey  OrderDateKey  DueDateKey  ShipDateKey  CustomerKey  \
# 0             344      20050722    20050803     20050729        11000
# 1             353      20070722    20070803     20070729        11000
# 2             485      20070722    20070803     20070729        11000
# 3             573      20071104    20071116     20071111        11000
# 4             541      20071104    20071116     20071111        11000
# ...           ...           ...         ...          ...          ...
# 60393         217      20080118    20080130     20080125        29480
# 60394         225      20080118    20080130     20080125        29480
# 60395         349      20060213    20060225     20060220        29481
# 60396         358      20070322    20070403     20070329        29482
# 60397         360      20070313    20070325     20070320        29483
#
#        PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# 0                 1            6                  9          SO43793
# 1                 2            6                  9          SO51522
# 2                 1            6                  9          SO51522
# 3                 1            6                  9          SO57418
# 4                 1            6                  9          SO57418
# ...             ...          ...                ...              ...
# 60393             1           98                 10          SO62341
# 60394             1           98                 10          SO62341
# 60395             1          100                  8          SO45427
# 60396             1          100                  7          SO49746
# 60397             1          100                  7          SO49665
#
#        SalesOrderLineNumber  RevisionNumber  OrderQuantity  UnitPrice  \
# 0                         1               1             14  $3,399.99
# 1                         1               1              1  $2,319.99
# 2                         2               1              1     $21.98
# 3                         1               1              1  $2,384.07
# 4                         2               1              1     $28.99
# ...                     ...             ...            ...        ...
# 60393                     4               1             16     $34.99
# 60394                     5               1              3      $8.99
# 60395                     1               1             13  $3,374.99
# 60396                     1               1              6  $2,049.10
# 60397                     1               1              7  $2,049.10
#
#       ExtendedAmount  UnitPriceDiscountPct  DiscountAmount  \
# 0          $3,399.99                     0               0
# 1          $2,319.99                     0               0
# 2             $21.98                     0               0
# 3          $2,384.07                     0               0
# 4             $28.99                     0               0
# ...              ...                   ...             ...
# 60393         $34.99                     0               0
# 60394          $8.99                     0               0
# 60395      $3,374.99                     0               0
# 60396      $2,049.10                     0               0
# 60397      $2,049.10                     0               0
#
#       ProductStandardCost TotalProductCost SalesAmount   TaxAmt Freight  \
# 0               $1,912.15        $1,912.15   $3,399.99  $272.00  $85.00
# 1               $1,265.62        $1,265.62   $2,319.99  $185.60  $58.00
# 2                   $8.22            $8.22      $21.98    $1.76   $0.55
# 3               $1,481.94        $1,481.94   $2,384.07  $190.73  $59.60
# 4                  $10.84           $10.84      $28.99    $2.32   $0.72
# ...                   ...              ...         ...      ...     ...
# 60393              $13.09           $13.09      $34.99    $2.80   $0.87
# 60394               $6.92            $6.92       $8.99    $0.72   $0.22
# 60395           $1,898.09        $1,898.09   $3,374.99  $270.00  $84.37
# 60396           $1,105.81        $1,105.81   $2,049.10  $163.93  $51.23
# 60397           $1,105.81        $1,105.81   $2,049.10  $163.93  $51.23
#
#        CarrierTrackingNumber  CustomerPONumber   OrderDate     DueDate  \
# 0                        NaN               NaN  22/07/2021  03/08/2021
# 1                        NaN               NaN  22/07/2022  03/08/2022
# 2                        NaN               NaN  22/07/2022  03/08/2022
# 3                        NaN               NaN  04/11/2022  16/11/2022
# 4                        NaN               NaN  04/11/2022  16/11/2022
# ...                      ...               ...         ...         ...
# 60393                    NaN               NaN  18/01/2022  30/01/2022
# 60394                    NaN               NaN  18/01/2022  30/01/2022
# 60395                    NaN               NaN  13/02/2021  25/02/2021
# 60396                    NaN               NaN  22/03/2022  03/04/2022
# 60397                    NaN               NaN  13/03/2022  25/03/2022
#
#          ShipDate
# 0      29/07/2021
# 1      29/07/2022
# 2      29/07/2022
# 3      11/11/2022
# 4      11/11/2022
# ...           ...
# 60393  25/01/2022
# 60394  25/01/2022
# 60395  20/02/2021
# 60396  29/03/2022
# 60397  20/03/2022
#
# [60398 rows x 26 columns]

# %%
# we need to fix the sales amount since it is string and contain dollar sign
df_sales['SalesAmountFix'] = (df_sales['SalesAmount'].str[1:]).str.replace(',','').astype(float)

# %%
# create dataframe for all customers orders count and total amount
df_customers_orders = df_sales.groupby('CustomerKey', as_index=False).agg(**{'CountSalesOrders' : ('SalesOrderNumber' , 'nunique'), 'TotalAmount' : ('SalesAmountFix' , 'sum')}).reset_index()
df_customers_orders
# Out:
#        index  CustomerKey  CountSalesOrders  TotalAmount
# 0          0        11000                 3      8248.99
# 1          1        11001                 3      6383.88
# 2          2        11002                 3      8114.04
# 3          3        11003                 3      8139.29
# 4          4        11004                 3      8196.01
# ...      ...          ...               ...          ...
# 18479  18479        29479                 1      2049.10
# 18480  18480        29480                 1      2442.03
# 18481  18481        29481                 1      3374.99
# 18482  18482        29482                 1      2049.10
# 18483  18483        29483                 1      2049.10
#
# [18484 rows x 4 columns]

# %%
# to make sure count and sum is correct
df_test_result = df_sales[(df_sales['CustomerKey'] == 11000)]
df_test_result
# Out:
#    ProductKey  OrderDateKey  DueDateKey  ShipDateKey  CustomerKey  \
# 0         344      20050722    20050803     20050729        11000
# 1         353      20070722    20070803     20070729        11000
# 2         485      20070722    20070803     20070729        11000
# 3         573      20071104    20071116     20071111        11000
# 4         541      20071104    20071116     20071111        11000
# 5         530      20071104    20071116     20071111        11000
# 6         214      20071104    20071116     20071111        11000
# 7         488      20071104    20071116     20071111        11000
#
#    PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# 0             1            6                  9          SO43793
# 1             2            6                  9          SO51522
# 2             1            6                  9          SO51522
# 3             1            6                  9          SO57418
# 4             1            6                  9          SO57418
# 5             1            6                  9          SO57418
# 6             1            6                  9          SO57418
# 7             1            6                  9          SO57418
#
#    SalesOrderLineNumber  RevisionNumber  OrderQuantity  UnitPrice  \
# 0                     1               1             14  $3,399.99
# 1                     1               1              1  $2,319.99
# 2                     2               1              1     $21.98
# 3                     1               1              1  $2,384.07
# 4                     2               1              1     $28.99
# 5                     3               1              1      $4.99
# 6                     4               1              1     $34.99
# 7                     5               1              1     $53.99
#
#   ExtendedAmount  UnitPriceDiscountPct  DiscountAmount ProductStandardCost  \
# 0      $3,399.99                     0               0           $1,912.15
# 1      $2,319.99                     0               0           $1,265.62
# 2         $21.98                     0               0               $8.22
# 3      $2,384.07                     0               0           $1,481.94
# 4         $28.99                     0               0              $10.84
# 5          $4.99                     0               0               $1.87
# 6         $34.99                     0               0              $13.09
# 7         $53.99                     0               0              $41.57
#
#   TotalProductCost SalesAmount   TaxAmt Freight  CarrierTrackingNumber  \
# 0        $1,912.15   $3,399.99  $272.00  $85.00                    NaN
# 1        $1,265.62   $2,319.99  $185.60  $58.00                    NaN
# 2            $8.22      $21.98    $1.76   $0.55                    NaN
# 3        $1,481.94   $2,384.07  $190.73  $59.60                    NaN
# 4           $10.84      $28.99    $2.32   $0.72                    NaN
# 5            $1.87       $4.99    $0.40   $0.12                    NaN
# 6           $13.09      $34.99    $2.80   $0.87                    NaN
# 7           $41.57      $53.99    $4.32   $1.35                    NaN
#
#    CustomerPONumber   OrderDate     DueDate    ShipDate  SalesAmountFix
# 0               NaN  22/07/2021  03/08/2021  29/07/2021         3399.99
# 1               NaN  22/07/2022  03/08/2022  29/07/2022         2319.99
# 2               NaN  22/07/2022  03/08/2022  29/07/2022           21.98
# 3               NaN  04/11/2022  16/11/2022  11/11/2022         2384.07
# 4               NaN  04/11/2022  16/11/2022  11/11/2022           28.99
# 5               NaN  04/11/2022  16/11/2022  11/11/2022            4.99
# 6               NaN  04/11/2022  16/11/2022  11/11/2022           34.99
# 7               NaN  04/11/2022  16/11/2022  11/11/2022           53.99

# %%
# categorizing customers
df_customers_orders['CustomerCategory'] = df_customers_orders.loc[:,'CustomerCategory']= ['VIP' if d1>=2 and d2>=100 else 'Loyal' if d1>=2 else 'Periodic buyers' for d1,d2 in zip(df_customers_orders.CountSalesOrders,df_customers_orders.TotalAmount)]
df_customers_orders.head(100)
# Out:
#     index  CustomerKey  CountSalesOrders  TotalAmount CustomerCategory
# 0       0        11000                 3      8248.99              VIP
# 1       1        11001                 3      6383.88              VIP
# 2       2        11002                 3      8114.04              VIP
# 3       3        11003                 3      8139.29              VIP
# 4       4        11004                 3      8196.01              VIP
# ..    ...          ...               ...          ...              ...
# 95     95        11095                 3      8158.01              VIP
# 96     96        11096                 3      8063.04              VIP
# 97     97        11097                 3      8099.03              VIP
# 98     98        11098                 3        88.96            Loyal
# 99     99        11099                 3      8215.99              VIP
#
# [100 rows x 5 columns]

# %%
# add flag for having childern or no
df_customers['HaveChildern'] = [True if d1>0 else False for d1 in df_customers.TotalChildren]

# %%
# join 2 dataframes together for customers and customer orders and total amounts
df_customers_revenue = pd.concat([df_customers.set_index('CustomerKey'), df_customers_orders.set_index('CustomerKey')], axis=1, join='inner').reset_index()
df_customers_revenue
# Out:
#        CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName  \
# 0            11000            26           AW00011000   NaN        Jon
# 1            11001            37           AW00011001   NaN     Eugene
# 2            11002            31           AW00011002   NaN      Ruben
# 3            11003            11           AW00011003   NaN    Christy
# 4            11004            19           AW00011004   NaN  Elizabeth
# ...            ...           ...                  ...   ...        ...
# 18479        29479           209           AW00029479   NaN      Tommy
# 18480        29480           248           AW00029480   NaN       Nina
# 18481        29481           120           AW00029481   NaN       Ivan
# 18482        29482           179           AW00029482   NaN    Clayton
# 18483        29483           217           AW00029483   NaN      Jésus
#
#       MiddleName LastName  NameStyle   BirthDate MaritalStatus Suffix Gender  \
# 0              V     Yang      False  1962-12-23             M    NaN      M
# 1              L    Huang      False  1976-06-23             S    NaN      M
# 2            NaN   Torres      False  1966-08-19             M    NaN      M
# 3            NaN      Zhu      False  1987-12-09             S    NaN      F
# 4            NaN  Johnson      False  1990-06-06             S    NaN      F
# ...          ...      ...        ...         ...           ...    ...    ...
# 18479          L     Tang      False  1996-05-13             M    NaN      M
# 18480          W     Raji      False  1971-09-21             S    NaN      F
# 18481        NaN     Suri      False  1993-11-16             S    NaN      M
# 18482        NaN    Zhang      False  1978-04-08             M    NaN      M
# 18483          L  Navarro      False  1986-05-08             M    NaN      M
#
#                          EmailAddress YearlyIncome  TotalChildren  \
# 0           jon24@adventure-works.com   $90,000.00              2
# 1        eugene10@adventure-works.com   $60,000.00              3
# 2         ruben35@adventure-works.com   $60,000.00              3
# 3       christy12@adventure-works.com   $70,000.00              0
# 4      elizabeth5@adventure-works.com   $80,000.00              5
# ...                               ...          ...            ...
# 18479      tommy2@adventure-works.com   $30,000.00              1
# 18480      nina21@adventure-works.com   $30,000.00              3
# 18481       ivan0@adventure-works.com   $30,000.00              3
# 18482    clayton0@adventure-works.com   $30,000.00              3
# 18483      jésus9@adventure-works.com   $30,000.00              0
#
#        NumberChildrenAtHome EnglishEducation       SpanishEducation  \
# 0                         0        Bachelors           Licenciatura
# 1                         3        Bachelors           Licenciatura
# 2                         3        Bachelors           Licenciatura
# 3                         0        Bachelors           Licenciatura
# 4                         5        Bachelors           Licenciatura
# ...                     ...              ...                    ...
# 18479                     0  Graduate Degree  Estudios de postgrado
# 18480                     0  Graduate Degree  Estudios de postgrado
# 18481                     0  Graduate Degree  Estudios de postgrado
# 18482                     0        Bachelors           Licenciatura
# 18483                     0        Bachelors           Licenciatura
#
#       FrenchEducation EnglishOccupation SpanishOccupation FrenchOccupation  \
# 0             Bac + 4      Professional       Profesional            Cadre
# 1             Bac + 4      Professional       Profesional            Cadre
# 2             Bac + 4      Professional       Profesional            Cadre
# 3             Bac + 4      Professional       Profesional            Cadre
# 4             Bac + 4      Professional       Profesional            Cadre
# ...               ...               ...               ...              ...
# 18479         Bac + 3          Clerical    Administrativo          Employé
# 18480         Bac + 3          Clerical    Administrativo          Employé
# 18481         Bac + 3          Clerical    Administrativo          Employé
# 18482         Bac + 4          Clerical    Administrativo          Employé
# 18483         Bac + 4          Clerical    Administrativo          Employé
#
#        HouseOwnerFlag  NumberCarsOwned               AddressLine1  \
# 0                   1                0            3761 N. 14th St
# 1                   0                1                 2243 W St.
# 2                   1                1           5844 Linden Land
# 3                   0                1           1825 Village Pl.
# 4                   1                4        7553 Harness Circle
# ...               ...              ...                        ...
# 18479               1                0          111, rue Maillard
# 18480               1                0          9 Katherine Drive
# 18481               0                0                Knaackstr 4
# 18482               1                0     1080, quai de Grenelle
# 18483               1                0  244, rue de la Centenaire
#
#       AddressLine2                Phone DateFirstPurchase CommuteDistance  \
# 0              NaN  1 (11) 500 555-0162         22-Jul-05       1-2 Miles
# 1              NaN  1 (11) 500 555-0110         18-Jul-05       0-1 Miles
# 2              NaN  1 (11) 500 555-0184         10-Jul-05       2-5 Miles
# 3              NaN  1 (11) 500 555-0162         01-Jul-05      5-10 Miles
# 4              NaN  1 (11) 500 555-0131         26-Jul-05       1-2 Miles
# ...            ...                  ...               ...             ...
# 18479          NaN  1 (11) 500 555-0136         08-Mar-07       0-1 Miles
# 18480          NaN  1 (11) 500 555-0146         18-Jan-08       0-1 Miles
# 18481          NaN  1 (11) 500 555-0144         13-Feb-06       0-1 Miles
# 18482          NaN  1 (11) 500 555-0137         22-Mar-07       0-1 Miles
# 18483          NaN  1 (11) 500 555-0141         13-Mar-07       0-1 Miles
#
#        age  HaveChildern  index  CountSalesOrders  TotalAmount  \
# 0       62          True      0                 3      8248.99
# 1       48          True      1                 3      6383.88
# 2       58          True      2                 3      8114.04
# 3       37         False      3                 3      8139.29
# 4       34          True      4                 3      8196.01
# ...    ...           ...    ...               ...          ...
# 18479   28          True  18479                 1      2049.10
# 18480   53          True  18480                 1      2442.03
# 18481   31          True  18481                 1      3374.99
# 18482   46          True  18482                 1      2049.10
# 18483   38         False  18483                 1      2049.10
#
#       CustomerCategory
# 0                  VIP
# 1                  VIP
# 2                  VIP
# 3                  VIP
# 4                  VIP
# ...                ...
# 18479  Periodic buyers
# 18480  Periodic buyers
# 18481  Periodic buyers
# 18482  Periodic buyers
# 18483  Periodic buyers
#
# [18484 rows x 35 columns]

# %%
# get total revenue based on customers having childern or not
df_customers_revenue_child = df_customers_revenue.groupby('HaveChildern', as_index=False).agg(**{'SumTotalAmount' : ('TotalAmount' , 'sum')}).reset_index()
df_customers_revenue_child
# Out:
#    index  HaveChildern  SumTotalAmount
# 0      0         False      8634027.29
# 1      1          True     20724650.60

# %%
# get total revenue based on customers gender
df_customers_revenue_gender = df_customers_revenue.groupby('Gender', as_index=False).agg(**{'SumTotalAmount' : ('TotalAmount' , 'sum')}).reset_index()
df_customers_revenue_gender
# Out:
#    index Gender  SumTotalAmount
# 0      0      F     14813619.09
# 1      1      M     14545058.80

# %%
# get top 10 customers who spent more
df_top_customers = df_customers_revenue.sort_values('TotalAmount', ascending=False).head(10)
df_top_customers
# Out:
#       CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName  \
# 1301        12301           223           AW00012301   NaN    Nichole
# 1132        12132           224           AW00012132   NaN    Kaitlyn
# 1308        12308           184           AW00012308   NaN   Margaret
# 1131        12131           186           AW00012131   NaN    Randall
# 1300        12300           180           AW00012300   NaN    Adriana
# 1321        12321           211           AW00012321   NaN       Rosa
# 1124        12124           192           AW00012124   NaN     Brandi
# 1307        12307           226           AW00012307   NaN       Brad
# 1296        12296           211           AW00012296   NaN  Francisco
# 433         11433           224           AW00011433   NaN    Maurice
#
#      MiddleName   LastName  NameStyle   BirthDate MaritalStatus Suffix Gender  \
# 1301        NaN       Nara      False  1988-11-03             S    NaN      F
# 1132          J  Henderson      False  1961-07-06             M    NaN      F
# 1308        NaN         He      False  1994-01-16             M    NaN      F
# 1131          M  Dominguez      False  1988-04-06             M    NaN      M
# 1300          L   Gonzalez      False  1966-07-21             S    NaN      F
# 1321          K         Hu      False  1964-10-14             M    NaN      F
# 1124          D       Gill      False  1971-06-14             S    NaN      F
# 1307        NaN        She      False  1963-01-11             M    NaN      M
# 1296          A       Sara      False  1998-08-29             M    NaN      M
# 433           M       Shan      False  1996-04-27             M    NaN      M
#
#                          EmailAddress YearlyIncome  TotalChildren  \
# 1301    nichole16@adventure-works.com  $100,000.00              2
# 1132    kaitlyn72@adventure-works.com  $110,000.00              3
# 1308   margaret25@adventure-works.com  $100,000.00              3
# 1131    randall14@adventure-works.com   $90,000.00              2
# 1300    adriana19@adventure-works.com   $80,000.00              5
# 1321       rosa20@adventure-works.com   $70,000.00              5
# 1124     brandi13@adventure-works.com  $110,000.00              2
# 1307        brad1@adventure-works.com   $90,000.00              4
# 1296  francisco11@adventure-works.com   $70,000.00              5
# 433     maurice11@adventure-works.com   $80,000.00              5
#
#       NumberChildrenAtHome     EnglishEducation  \
# 1301                     3            Bachelors
# 1132                     4      Partial College
# 1308                     4          High School
# 1131                     1          High School
# 1300                     0      Partial College
# 1321                     2  Partial High School
# 1124                     4      Partial College
# 1307                     2          High School
# 1296                     1          High School
# 433                      2          High School
#
#                         SpanishEducation FrenchEducation EnglishOccupation  \
# 1301                        Licenciatura         Bac + 4        Management
# 1132  Estudios universitarios (en curso)    Baccalauréat      Professional
# 1308                Educación secundaria         Bac + 2      Professional
# 1131                Educación secundaria         Bac + 2      Professional
# 1300  Estudios universitarios (en curso)    Baccalauréat      Professional
# 1321     Educación secundaria (en curso)      Niveau bac    Skilled Manual
# 1124  Estudios universitarios (en curso)    Baccalauréat      Professional
# 1307                Educación secundaria         Bac + 2      Professional
# 1296                Educación secundaria         Bac + 2      Professional
# 433                 Educación secundaria         Bac + 2      Professional
#
#          SpanishOccupation FrenchOccupation  HouseOwnerFlag  NumberCarsOwned  \
# 1301               Gestión        Direction               1                4
# 1132           Profesional            Cadre               1                4
# 1308           Profesional            Cadre               1                2
# 1131           Profesional            Cadre               0                2
# 1300           Profesional            Cadre               1                2
# 1321  Obrero especializado       Technicien               1                2
# 1124           Profesional            Cadre               1                3
# 1307           Profesional            Cadre               1                1
# 1296           Profesional            Cadre               0                2
# 433            Profesional            Cadre               0                2
#
#                           AddressLine1 AddressLine2                Phone  \
# 1301             21, avenue de la Gare          NaN  1 (11) 500 555-0152
# 1132              2222, rue Ste-Honoré          NaN  1 (11) 500 555-0154
# 1308  12bis, boulevard du Montparnasse          NaN  1 (11) 500 555-0112
# 1131              244, rue des Rosiers          NaN  1 (11) 500 555-0136
# 1300              310, rue des Rosiers          NaN  1 (11) 500 555-0129
# 1321               28, place du Tertre          NaN  1 (11) 500 555-0192
# 1124                8, rue de l´Avenir          NaN  1 (11) 500 555-0115
# 1307              12, rue Henri Gagnon          NaN  1 (11) 500 555-0136
# 1296                 24, rue Descartes          NaN  1 (11) 500 555-0166
# 433                   59, rue Montcalm          NaN  1 (11) 500 555-0130
#
#      DateFirstPurchase CommuteDistance  age  HaveChildern  index  \
# 1301         10-Nov-05       10+ Miles   36          True   1301
# 1132         02-Aug-05      5-10 Miles   63          True   1132
# 1308         04-Dec-05       10+ Miles   30          True   1308
# 1131         24-Aug-05       2-5 Miles   36          True   1131
# 1300         24-Nov-05       10+ Miles   58          True   1300
# 1321         03-Dec-05       2-5 Miles   60          True   1321
# 1124         01-Aug-05      5-10 Miles   53          True   1124
# 1307         29-Nov-05       2-5 Miles   61          True   1307
# 1296         19-Nov-05       2-5 Miles   26          True   1296
# 433          05-Jun-07       2-5 Miles   28          True    433
#
#       CountSalesOrders  TotalAmount CustomerCategory
# 1301                 5     13295.38              VIP
# 1132                 5     13294.27              VIP
# 1308                 5     13269.27              VIP
# 1131                 5     13265.99              VIP
# 1300                 5     13242.70              VIP
# 1321                 5     13215.65              VIP
# 1124                 5     13195.64              VIP
# 1307                 5     13173.19              VIP
# 1296                 5     13164.64              VIP
# 433                  6     12909.67              VIP
